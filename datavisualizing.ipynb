# %% [markdown]
# # Table

# %%
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt
# Load dataset

# Load dataset
def load_dataset(file_path):
  return pd.read_csv(file_path)


df = load_dataset("./Health_heart_experimental.csv")
df.head(5)
# Out:
#    Unnamed: 0  age  sex  SysBP  DiaBP   HR  weightKg  heightCm   BMI  \
# 0           0   64    1    141     96  128        69       147  32.0
# 1           1   21    1    109    100  106        48       150  21.0
# 2           2   30    0    112     73  126        69       183  21.0
# 3           3   35    1    106     90  130        45       149  20.0
# 4           4   39    0    140     90  112        92       166  33.0
#
#    indication
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1

# %% [markdown]
# # Linegraph

# %%
sns.lineplot(data=df, x='age', y='HR', marker='o')
plt.title("Age vs HeartRate")
plt.xlabel("Age")
plt.ylabel("HeartRate")
plt.show()

# %% [markdown]
# # Bar Plot

# %%
plt.figure(figsize=(10, 6))
df.groupby('sex')['weightKg'].mean().plot(kind='bar', color=['blue', 'red'], alpha=0.7)
plt.title("Average weight of Male and Female")
plt.xlabel("Sex (0=Female, 1=Male)")
plt.ylabel("Average weight")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # pie chart

# %%
plt.figure(figsize=(8, 8))
df['sex'].value_counts().plot.pie(autopct='%1.1f%%', colors=['skyblue', 'salmon'], startangle=90)
plt.title("Distribution of Male and Female")
plt.xlabel(" (0=Female, 1=Male)")
plt.show()

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x='sex',y='age',hue='BMI',data=df)
plt.xlabel(" (0=Female, 1=Male)")
# Out:
# Text(0.5, 0, ' (0=Female, 1=Male)')

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=20, kde=True, color='purple', alpha=0.7)
plt.title("Distribution of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(x='age', y='SysBP',hue='sex',style ='indication',data=df)
plt.xlabel(" (0=Female, 1=Male)")
plt.show()
